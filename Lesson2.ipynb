# %% [markdown]
# ## Lesson 2

# %%
import numpy as np
import pandas as pd

# %%
path = r'Data\OnlineRetail.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                Description  Quantity  \
# 0    539993     22386    JUMBO BAG PINK POLKADOT        10
# 1    539993     21499         BLUE POLKADOT WRAP        25
# 2    539993     21498        RED RETROSPOT WRAP         25
# 3    539993     22379   RECYCLING BAG RETROSPOT          5
# 4    539993     20718  RED RETROSPOT SHOPPER BAG        10
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2011-01-04 10:00:00       1.95     13313.0  United Kingdom
# 1  2011-01-04 10:00:00       0.42     13313.0  United Kingdom
# 2  2011-01-04 10:00:00       0.42     13313.0  United Kingdom
# 3  2011-01-04 10:00:00       2.10     13313.0  United Kingdom
# 4  2011-01-04 10:00:00       1.25     13313.0  United Kingdom

# %%
url = r"https://raw.githubusercontent.com/ntlong-NEU/DSEB65B-DataPre-Visual/refs/heads/main/Data/OnlineRetail.csv"
pd.read_csv(url)
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 0         539993     22386       JUMBO BAG PINK POLKADOT        10
# 1         539993     21499            BLUE POLKADOT WRAP        25
# 2         539993     21498           RED RETROSPOT WRAP         25
# 3         539993     22379      RECYCLING BAG RETROSPOT          5
# 4         539993     20718     RED RETROSPOT SHOPPER BAG        10
# ...          ...       ...                           ...       ...
# 203417    558637     22032  BOTANICAL LILY GREETING CARD        12
# 203418    558637     22028  PENNY FARTHING BIRTHDAY CARD        12
# 203419    558637     22033  BOTANICAL ROSE GREETING CARD        12
# 203420    558637     22029        SPACEBOY BIRTHDAY CARD        12
# 203421    558637     22024    RAINY LADIES BIRTHDAY CARD        12
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# 0       2011-01-04 10:00:00       1.95     13313.0  United Kingdom
# ...

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                       Description  Quantity  \
# 0    539993     22386           JUMBO BAG PINK POLKADOT        10
# 1    539993     21499                BLUE POLKADOT WRAP        25
# 2    539993     21498               RED RETROSPOT WRAP         25
# 3    539993     22379          RECYCLING BAG RETROSPOT          5
# 4    539993     20718         RED RETROSPOT SHOPPER BAG        10
# 5    539993    85099B           JUMBO BAG RED RETROSPOT        10
# 6    539993     20682  RED RETROSPOT CHILDRENS UMBRELLA         6
# 7    539993     22961            JAM MAKING SET PRINTED        12
# 8    539993     22667             RECIPE BOX RETROSPOT          6
# 9    539993     22898     CHILDRENS APRON APPLES DESIGN         8
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2011-01-04 10:00:00       1.95     13313.0  United Kingdom
# 1  2011-01-04 10:00:00       0.42     13313.0  United Kingdom
# ...

# %%
df.tail(2)
# Out:
#        InvoiceNo StockCode                 Description  Quantity  \
# 203420    558637     22029      SPACEBOY BIRTHDAY CARD        12
# 203421    558637     22024  RAINY LADIES BIRTHDAY CARD        12
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# 203420  2011-06-30 20:08:00       0.42     17891.0  United Kingdom
# 203421  2011-06-30 20:08:00       0.42     17891.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203422 entries, 0 to 203421
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    203422 non-null  object
#  1   StockCode    203422 non-null  object
#  2   Description  202623 non-null  object
#  3   Quantity     203422 non-null  int64
#  4   InvoiceDate  203422 non-null  object
#  5   UnitPrice    203422 non-null  float64
#  6   CustomerID   150039 non-null  float64
#  7   Country      203422 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 12.4+ MB

# %%
type(df['InvoiceDate'][1])
# Out:
# str

# %%
# First, you may need to install the library:
#!pip install yfinance
import yfinance as yf

# %%
# Fetch Apple stock data ('AAPL') from Yahoo Finance
aapl = yf.download('AAPL', start='2023-01-01', end='2023-12-31')
aapl.head()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2023-01-03  123.330635  129.079551  122.443150  128.468178  112117500
# 2023-01-04  124.602722  126.870739  123.340524  125.125350   89113600
# 2023-01-05  123.281334  125.993089  123.024955  125.361991   80962700
# 2023-01-06  127.817352  128.478033  123.153137  124.257564   87754700
# 2023-01-09  128.339981  131.554653  128.083602  128.655538   70790800

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  203422.000000  203422.000000  150039.000000
# mean        9.585684       4.877820   15240.234832
# std       240.921315     113.686676    1717.658493
# min    -74215.000000       0.000000   12346.000000
# 25%         1.000000       1.250000   13791.000000
# 50%         3.000000       2.100000   15061.000000
# 75%        10.000000       4.130000   16771.000000
# max     74215.000000   38970.000000   18287.000000

# %%
df[df['UnitPrice']==0]
# Out:
#        InvoiceNo StockCode Description  Quantity          InvoiceDate  \
# 17        539994     22830         NaN        -1  2011-01-04 10:09:00
# 18        539995     85064         NaN       -12  2011-01-04 10:12:00
# 19        539996     21784         NaN       -10  2011-01-04 10:12:00
# 20        539997     84689         NaN         5  2011-01-04 10:15:00
# 21        539998     84675         NaN         2  2011-01-04 10:16:00
# ...          ...       ...         ...       ...                  ...
# 200909    558457     21147           ?       -95  2011-06-29 13:59:00
# 201042    558464     35966         NaN       -20  2011-06-29 15:17:00
# 201779    558476    84597B     damages        -6  2011-06-29 16:04:00
# 201780    558477    84597C         NaN        -1  2011-06-29 16:04:00
# 201917    558520     21896         NaN       -38  2011-06-30 10:25:00
#
#         UnitPrice  CustomerID         Country
# 17            0.0         NaN  United Kingdom
# ...

# %%
df[df["Quantity"]<0]
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 17        539994     22830                                 NaN        -1
# 18        539995     85064                                 NaN       -12
# 19        539996     21784                                 NaN       -10
# 22        539999     20892                                 NaN        -1
# 23        540000     84499                                 NaN        -9
# ...          ...       ...                                 ...       ...
# 201945   C558531     22424              ENAMEL BREAD BIN CREAM        -1
# 202318   C558553     23170            REGENCY TEA PLATE ROSES       -576
# 202427   C558559     20749          ASSORTED COLOUR MINI CASES        -1
# 202627   C558575     22693  GROW A FLYTRAP OR SUNFLOWER IN TIN       -24
# 203075   C558615     21845               DAIRY MAID STRIPE MUG        -4
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df_OR = pd.read_excel('Data\Online_Retail.xlsx')
df_OR.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df_OR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
type(df_OR['InvoiceNo'][1])
# Out:
# int

# %%
df_OR['InvoiceNo'] = df_OR['InvoiceNo'].astype(str)
df_OR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df_OR["InvoiceNo"][1]
# Out:
# '536365'

# %%
data = {'Name': ['John', 'Anna', 'Peter', 'Linda', 'James'],
        'Age': [28, 22, np.nan, 32, 25],
        'City': ['New York', 'Paris', 'Berlin', np.nan, 'London'],
        'Salary': [70000, np.nan, 60000, 85000, np.nan]}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name   Age      City   Salary
# 0   John  28.0  New York  70000.0
# 1   Anna  22.0     Paris      NaN
# 2  Peter   NaN    Berlin  60000.0
# 3  Linda  32.0       NaN  85000.0
# 4  James  25.0    London      NaN

# %%
df['Age'].fillna(df['Age'].mean(), inplace= True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6712\1444409324.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace= True)

# %%
df
# Out:
#     Name    Age      City   Salary
# 0   John  28.00  New York  70000.0
# 1   Anna  22.00     Paris      NaN
# 2  Peter  26.75    Berlin  60000.0
# 3  Linda  32.00       NaN  85000.0
# 4  James  25.00    London      NaN

# %%
df['Salary'].fillna(method = 'bfill')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6712\1335963949.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Salary'].fillna(method = 'bfill')
# 0    70000.0
# 1    60000.0
# 2    60000.0
# 3    85000.0
# 4        NaN
# Name: Salary, dtype: float64

# %%
df['Salary'].fillna(method = 'ffill')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6712\694346041.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Salary'].fillna(method = 'ffill')
# 0    70000.0
# 1    70000.0
# 2    60000.0
# 3    85000.0
# 4    85000.0
# Name: Salary, dtype: float64

# %%
df_OR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df_OR.drop_duplicates(inplace = True)
df_OR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 536641 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    536641 non-null  object
#  1   StockCode    536641 non-null  object
#  2   Description  535187 non-null  object
#  3   Quantity     536641 non-null  int64
#  4   InvoiceDate  536641 non-null  datetime64[ns]
#  5   UnitPrice    536641 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      536641 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 36.8+ MB

# %%
df_OR.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %%
df_OR.dropna(subset=['CustomerID'], inplace=True)
df_OR.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df_OR['CustomerID'] = df_OR['CustomerID'].astype(int).astype(str)
df_OR['InvoiceDate'] = pd.to_datetime(df_OR['InvoiceDate'])
df_OR.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice
# count  401604.000000                         401604  401604.000000
# mean       12.183273  2011-07-10 12:08:23.848567552       3.474064
# min    -80995.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-06 15:02:00       1.250000
# 50%         5.000000            2011-07-29 15:40:00       1.950000
# 75%        12.000000            2011-10-20 11:58:30       3.750000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       250.283037                            NaN      69.764035

# %%
df_OR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 401604 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401604 non-null  object
#  1   StockCode    401604 non-null  object
#  2   Description  401604 non-null  object
#  3   Quantity     401604 non-null  int64
#  4   InvoiceDate  401604 non-null  datetime64[ns]
#  5   UnitPrice    401604 non-null  float64
#  6   CustomerID   401604 non-null  object
#  7   Country      401604 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 27.6+ MB

# %%
df_OR  = df_OR[df_OR['Quantity']>0]
df_OR.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice
# count  392732.000000                         392732  392732.000000
# mean       13.153718  2011-07-10 19:15:24.576301568       3.125596
# min         1.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-07 11:12:00       1.250000
# 50%         6.000000            2011-07-31 12:02:00       1.950000
# 75%        12.000000            2011-10-20 12:53:00       3.750000
# max     80995.000000            2011-12-09 12:50:00    8142.750000
# std       181.588420                            NaN      22.240725

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                   columns=['letter', 'number'])
df2 = pd.DataFrame([['c', 3, 'cat'], ['d', 4, 'dog']],
                   columns=['letter', 'number', 'animal'])
df1
# Out:
#   letter  number
# 0      a       1
# 1      b       2

# %%
df2
# Out:
#   letter  number animal
# 0      c       3    cat
# 1      d       4    dog

# %%
# axis = 0, jion = 'outer'
pd.concat([df1,df2])
# Out:
#   letter  number animal
# 0      a       1    NaN
# 1      b       2    NaN
# 0      c       3    cat
# 1      d       4    dog

# %%
# axis = 0, jion = 'inner'
pd.concat([df1,df2], join='inner', ignore_index= True)
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 2      c       3
# 3      d       4

# %%
# axis = 1, jion = 'outer'
pd.concat([df1,df2], axis=1, join='outer')
# Out:
#   letter  number letter  number animal
# 0      a       1      c       3    cat
# 1      b       2      d       4    dog

# %%
# axis = 1, jion = 'outer'
pd.concat([df1,df2], axis=1, join='inner')
# Out:
#   letter  number letter  number animal
# 0      a       1      c       3    cat
# 1      b       2      d       4    dog

# %%
pd.concat([df1,df2], axis=0, keys = ['df1','df2'])
# Out:
#       letter  number animal
# df1 0      a       1    NaN
#     1      b       2    NaN
# df2 0      c       3    cat
#     1      d       4    dog

# %%
import seaborn as sns
tips = sns.load_dataset('tips').head
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df = tips.head(10)

# %%
df[df['sex'] == 'Male']['total_bill'].sum()
# Out:
# np.float64(145.79)

# %%
df1 = pd.Series({'Sex':'Male',
                    'TotalBill':df[df['sex'] == 'Male']['total_bill'].sum()})
df1
# Out:
# Sex            Male
# TotalBill    145.79
# dtype: object

# %%
{'Sex':'Male','TotalBill':df[df['sex'] == 'Male']['total_bill'].sum()}
# Out:
# {'Sex': 'Male', 'TotalBill': np.float64(145.79)}

# %%
df_OR.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom

# %%
url1 = 'https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-population.csv'
url2 = 'https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-areas.csv'
url3 = 'https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-abbrevs.csv'

pop = pd.read_csv(url1)
areas = pd.read_csv(url2)
abbrevs = pd.read_csv(url3)

# %%
pop.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
areas.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
abbrevs.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
df1 = pd.merge(abbrevs, areas, how='outer')
df1.head()
# Out:
#         state abbreviation  area (sq. mi)
# 0     Alabama           AL          52423
# 1      Alaska           AK         656425
# 2     Arizona           AZ         114006
# 3    Arkansas           AR          53182
# 4  California           CA         163707

# %%
pop.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
df2 = pd.merge(pop,df1,
         left_on="state/region", 
         right_on='abbreviation', 
         how='outer').drop(columns=['state/region','abbreviation'])

# %%
df2.head()
# Out:
#       ages    year  population   state  area (sq. mi)
# 0    total  1990.0    553290.0  Alaska       656425.0
# 1  under18  1990.0    177502.0  Alaska       656425.0
# 2    total  1992.0    588736.0  Alaska       656425.0
# 3  under18  1991.0    182180.0  Alaska       656425.0
# 4  under18  1992.0    184878.0  Alaska       656425.0

# %%
df2['ages'].unique()
# Out:
# array(['total', 'under18', nan], dtype=object)

# %%
df2.isnull().sum()
# Out:
# ages             0
# year             0
# population       0
# state            0
# area (sq. mi)    0
# dtype: int64

# %%
df2.drop_duplicates(inplace=True)
df2.drop

# %%
df2.dropna(inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2448 entries, 0 to 2543
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ages           2448 non-null   object
#  1   year           2448 non-null   float64
#  2   population     2448 non-null   float64
#  3   state          2448 non-null   object
#  4   area (sq. mi)  2448 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 114.8+ KB

# %%
df3=df2[(df2['ages'] == 'total')& (df2['year'] == 2010)]
# Out:
#       ages    year  population       state  area (sq. mi)
# 43   total  2010.0    713868.0      Alaska       656425.0
# 51   total  2010.0   4785570.0     Alabama        52423.0
# 141  total  2010.0   2922280.0    Arkansas        53182.0
# 149  total  2010.0   6408790.0     Arizona       114006.0
# 197  total  2010.0  37333601.0  California       163707.0

# %%
df3['density'] = df3['population'] / df3['area (sq. mi)']
df3.head(5)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6712\789052547.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['density'] = df3['population'] / df3['area (sq. mi)']
#       ages    year  population       state  area (sq. mi)     density
# 43   total  2010.0    713868.0      Alaska       656425.0    1.087509
# 51   total  2010.0   4785570.0     Alabama        52423.0   91.287603
# 141  total  2010.0   2922280.0    Arkansas        53182.0   54.948667
# 149  total  2010.0   6408790.0     Arizona       114006.0   56.214497
# 197  total  2010.0  37333601.0  California       163707.0  228.051342

# %%
df3['Rank'] = df3['density'].rank(ascending=False)
df3.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6712\3343658474.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Rank'] = df3['density'].rank(ascending=False)
#       ages    year  population       state  area (sq. mi)     density  Rank
# 43   total  2010.0    713868.0      Alaska       656425.0    1.087509  51.0
# 51   total  2010.0   4785570.0     Alabama        52423.0   91.287603  26.0
# 141  total  2010.0   2922280.0    Arkansas        53182.0   54.948667  35.0
# 149  total  2010.0   6408790.0     Arizona       114006.0   56.214497  34.0
# 197  total  2010.0  37333601.0  California       163707.0  228.051342  12.0

# %%
df3[['state', 'density','Rank']].sort_values(by='Rank')
# Out:
#                      state      density  Rank
# 341   District of Columbia  8898.897059   1.0
# 1493            New Jersey  1009.253268   2.0
# 1962          Rhode Island   681.339159   3.0
# 293            Connecticut   645.600649   4.0
# 954          Massachusetts   621.815538   5.0
# 965               Maryland   466.445797   6.0
# 427               Delaware   460.445752   7.0
# 1637              New York   356.094135   8.0
# 475                Florida   286.597129   9.0
# 1829          Pennsylvania   275.966651  10.0
# 1722                  Ohio   257.549634  11.0
# 197             California   228.051342  12.0
# 714               Illinois   221.687472  13.0
# 2261              Virginia   187.622273  14.0
# 725                Indiana   178.197831  15.0
# 1338        North Carolina   177.617157  16.0
# 485                Georgia   163.409902  17.0
# 2069             Tennessee   150.825298  18.0
# 1973        South Carolina   144.854594  19.0
# ...

# %%
planets = sns.load_dataset('planets')
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# 1. What is the total number of planets discovered?
#
# 2. What is the average orbital period of the discovered planets?
#
# 3. How many unique methods were used to discover the planets?
#
# 4. What is the maximum mass of the discovered planets?
#
# 5. What is the minimum distance of the discovered planets from Earth?

# %%
#1)
planets['number'].sum()
# Out:
# np.int64(1848)

# %%
#2)
planets['orbital_period'].mean()
# Out:
# np.float64(2002.9175960947582)

# %%
#3)
len(planets['method'].unique())
# Out:
# 10

# %%
#4)
planets['mass'].max()
# Out:
# np.float64(25.0)

# %%
#5)
planets['distance'].min()
# Out:
# np.float64(1.35)

# %%
planets['number'].value_counts()
# Out:
# number
# 1    595
# 2    259
# 3     88
# 4     32
# 5     30
# 6     24
# 7      7
# Name: count, dtype: int64

# %%
def groupbyhand(planets):
    mt_dict = {}
    for mt in planets['method'].unique():
        mt_dict[mt] = planets[planets['method'] == mt]['number'].sum()
    return pd.Series(mt_dict)

# %%
pd.Series(mt_dict)
# Out:
# Radial Velocity                  952
# Imaging                           50
# Eclipse Timing Variations         15
# Transit                          776
# Astrometry                         2
# Transit Timing Variations          9
# Orbital Brightness Modulation      5
# Microlensing                      27
# Pulsar Timing                     11
# Pulsation Timing Variations        1
# dtype: int64

# %%
list(planets[['method','number']].groupby('method'))
# Out:
# [('Astrometry',
#            method  number
#   113  Astrometry       1
#   537  Astrometry       1),
#  ('Eclipse Timing Variations',
#                          method  number
#   32  Eclipse Timing Variations       1
#   37  Eclipse Timing Variations       2
#   38  Eclipse Timing Variations       2
#   39  Eclipse Timing Variations       2
#   40  Eclipse Timing Variations       2
#   41  Eclipse Timing Variations       1
#   42  Eclipse Timing Variations       1
#   43  Eclipse Timing Variations       2
#   44  Eclipse Timing Variations       2),
#  ('Imaging',
#          method  number
#   29    Imaging       1
#   30    Imaging       1
#   31    Imaging       1
#   33    Imaging       1
#   34    Imaging       1
#   35    Imaging       1
#   36    Imaging       1
#   47    Imaging       1
#   54    Imaging       1
#   68    Imaging       1
#   69    Imaging       1
#   70    Imaging       1
#   71    Imaging       1
#   72    Imaging       1
#   73    Imaging       1
# ...

# %%
# %timeit planets[['method','number']].groupby('method').sum()
# Out:
# 1.74 ms ± 464 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit groupbyhand(planets)
# Out:
# 5.05 ms ± 687 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
